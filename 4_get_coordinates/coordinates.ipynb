# %%
import requests
import os
import pandas as pd
import time
from dotenv import load_dotenv
import logging

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

load_dotenv()

GEOCLIENT_KEY = os.getenv("GEOCLIENT_KEY")

url = "https://api.nyc.gov/geoclient/v2/address.json"

# %%
def get_lat_lon(house_number: str, street: str, borough: str) -> tuple:
    params = {
        "houseNumber": house_number,
        "street": street,
        "borough": borough
    }
    headers = {
        "Ocp-Apim-Subscription-Key": GEOCLIENT_KEY
    }
    response = requests.get(url, params=params, headers=headers)
    data = response.json()
    if "address" in data:
        lat = data["address"].get("latitude")
        lon = data["address"].get("longitude")
        return (lat, lon)
    return (None, None)

# %%
def process_listings_with_coordinates(input_file_path, batch_size=100, requests_per_minute=2000):
    """
    Process listings CSV file to add latitude and longitude coordinates.

    Args:
        input_file_path (str): Path to the input CSV file
        batch_size (int): Number of addresses to process in each batch
        requests_per_minute (int): Maximum requests per minute to stay under API limits

    Returns:
        str: Path to the output CSV file with coordinates
    """
    # Set up logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler('geocoding.log'),
            logging.StreamHandler()
        ]
    )

    # Load the CSV data
    logging.info(f"Loading data from {input_file_path}")
    df = pd.read_csv(input_file_path)
    total_rows = len(df)
    logging.info(f"Loaded {total_rows} listings")

    # Add latitude and longitude columns if they don't exist
    if 'LATITUDE' not in df.columns:
        df['LATITUDE'] = None
    if 'LONGITUDE' not in df.columns:
        df['LONGITUDE'] = None

    # Calculate time needed between requests to stay under rate limit
    seconds_per_request = 60 / requests_per_minute

    # Process in batches
    processed_count = 0
    error_count = 0

    # Find rows without coordinates
    rows_to_process = df[(df['LATITUDE'].isna()) | (df['LONGITUDE'].isna())].index
    logging.info(f"Found {len(rows_to_process)} listings without coordinates")

    # Generate output filename with timestamp
    output_file = "listings_with_coordinates.csv"

    try:
        for i, idx in enumerate(rows_to_process):
            row = df.loc[idx]

            # Clean building number (handle ranges like "303 TO 309")
            building_no = str(row['BUILDING_NO']).split(' TO ')[0].strip() if pd.notna(row['BUILDING_NO']) else ""

            # Process the address
            if pd.notna(row['BOROUGH']) and pd.notna(row['STREET']) and building_no:
                start_time = time.time()

                try:
                    lat, lon = get_lat_lon(
                        house_number=building_no,
                        street=str(row['STREET']),
                        borough=str(row['BOROUGH'])
                    )
                    df.at[idx, 'LATITUDE'] = lat
                    df.at[idx, 'LONGITUDE'] = lon
                    processed_count += 1

                    # Log progress periodically
                    if processed_count % 10 == 0:
                        logging.info(f"Processed {processed_count}/{len(rows_to_process)} addresses")

                except Exception as e:
                    logging.error(f"Error processing {building_no} {row['STREET']}, {row['BOROUGH']}: {str(e)}")
                    error_count += 1

                # Save progress after each batch
                if (i + 1) % batch_size == 0:
                    df.to_csv(output_file, index=False)
                    logging.info(f"Saved progress to {output_file} after {i+1} addresses")

                # Control rate limiting
                elapsed = time.time() - start_time
                if elapsed < seconds_per_request:
                    time.sleep(seconds_per_request - elapsed)

            # Save final progress
            if (i + 1) == len(rows_to_process):
                df.to_csv(output_file, index=False)

    except KeyboardInterrupt:
        logging.info("Process interrupted by user. Saving current progress...")
        df.to_csv(output_file, index=False)

    logging.info(f"Processing complete. Processed {processed_count} addresses with {error_count} errors")
    logging.info(f"Results saved to {output_file}")

    return output_file

# %%
# Test the get_lat_lon function with a single address
lat, long = get_lat_lon("246", "10th Avenue", "Manhattan")
print(f"Test coordinates: {lat}, {long}")

# %%
# Process the full dataset
input_path = '../2_flatten_and_clean_addresses/listings_flattened_and_cleaned_address.csv'
process_listings_with_coordinates(input_path)

# %%
df = pd.read_csv('listings_with_coordinates.csv')

# Filter rows where Latitude and Longitude are empty or NaN
filtered = df[(df['LATITUDE'].isna() | (df['LATITUDE'] == '')) &
              (df['LONGITUDE'].isna() | (df['LONGITUDE'] == ''))]
filtered
# Out:
#              BOROUGH    ZIP       BUILDING_NO CLEAN_BUILDING_NO  \
# 148        MANHATTAN  10002              37.5            37 1/2
# 234        MANHATTAN  10002             123.5           123 1/2
# 293        MANHATTAN  10002             168.5           168 1/2
# 401        MANHATTAN  10002              27.5            27 1/2
# 1267       MANHATTAN  10003              47.5            47 1/2
# 1268       MANHATTAN  10003              48.5            48 1/2
# 1387       MANHATTAN  10003              34.5            34 1/2
# 1390       MANHATTAN  10003              37.5            37 1/2
# 1473       MANHATTAN  10009             120.5           120 1/2
# 1979       MANHATTAN  10009              93.5            93 1/2
# 1984       MANHATTAN  10009              97.5            97 1/2
# 2320       MANHATTAN  10010              11.5            11 1/2
# 2724       MANHATTAN  10011             213.5           213 1/2
# 3646       MANHATTAN  10014              37.5            37 1/2
# 3767       MANHATTAN  10014              21.5            21 1/2
# 3855       MANHATTAN  10014             615.5           615 1/2
# 3863       MANHATTAN  10014               5.5             5 1/2
# 3881       MANHATTAN  10014              80.5            80 1/2
# 4425       MANHATTAN  10016             304.5           304 1/2
# 6659       MANHATTAN  10024              11.5            11 1/2
# 7813       MANHATTAN  10026              1829              1829
# 7817       MANHATTAN  10026              1845              1845
# 7819       MANHATTAN  10026      1849 TO 1851      1849 TO 1851
# 7827       MANHATTAN  10026              1925              1925
# 7829       MANHATTAN  10026              1949              1949
# 7834       MANHATTAN  10026      1976 TO 1980      1976 TO 1980
# 7877       MANHATTAN  10026      1991 TO 1999      1991 TO 1999
# 7878       MANHATTAN  10026          15 TO 19          15 TO 19
# 7945       MANHATTAN  10026           9 TO 11           9 TO 11
# 7951       MANHATTAN  10026        215 TO 221        215 TO 221
# 8227       MANHATTAN  10027              2035              2035
# 8506       MANHATTAN  10027      2041 TO 2049      2041 TO 2049
# 8720       MANHATTAN  10027      2167 TO 2177      2167 TO 2177
# 9851       MANHATTAN  10030              2308              2308
# 9854       MANHATTAN  10030      2321 TO 2339      2321 TO 2339
# 9857       MANHATTAN  10030      2363 TO 2369      2363 TO 2369
# 9867       MANHATTAN  10030              2484              2484
# 9869       MANHATTAN  10030              2492              2492
# 12027      MANHATTAN  10035            2291.5          2291 1/2
# 12286      MANHATTAN  10035              11.5            11 1/2
# 12431      MANHATTAN  10036             501.5           501 1/2
# 12752      MANHATTAN  10038              22.5            22 1/2
# 28925             Brighton Beach Avenue  8722.0  474.0      61       BROOKLYN
# 31293  Drive Martin L King Jr Boulevard  2527.0    1.0      60          BRONX
# 31294  Drive Martin L King Jr Boulevard  2526.0  158.0      60          BRONX
# 31296  Drive Martin L King Jr Boulevard  2526.0  159.0      60          BRONX
# 31297  Drive Martin L King Jr Boulevard  2528.0   11.0      60          BRONX
# 31298  Drive Martin L King Jr Boulevard  2537.0   47.0      60          BRONX
# 31623  Drive Martin L King Jr Boulevard  2534.0    3.0      60          BRONX
# 31865  Drive Martin L King Jr Boulevard  2868.0  100.0      60          BRONX
# 31866  Drive Martin L King Jr Boulevard  3211.0   42.0      60          BRONX
# 34062                  Botanical Square  3274.0   21.0      60          BRONX
# 37404  Drive Martin L King Jr Boulevard  3218.0   58.0      60          BRONX
# 38679                    Reed Mill Lane  5263.0  176.0      60          BRONX
# 38680                    Reed Mill Lane  5263.0  177.0      60          BRONX
# 38681                    Reed Mill Lane  5263.0  178.0      60          BRONX
# 38682                    Reed Mill Lane  5263.0  179.0      60          BRONX
# 42522                      224th Street     NaN    NaN      63       FLUSHING
# 48541                  Augustine Avenue     NaN    NaN      63   FAR ROCKAWAY
# 48928                       Harbor Loop  1243.0   64.0      64  STATEN ISLAND
#
#                    STATUS1               STATUS2               STATUS3  \
# 148    MULTIPLE DWELLING A                   NaN                   NaN
# 234    MULTIPLE DWELLING A                   NaN                   NaN
# 293    MULTIPLE DWELLING A                   NaN                   NaN
# 401    MULTIPLE DWELLING A                   NaN                   NaN
# 1267   MULTIPLE DWELLING A                   NaN                   NaN
# 1268   MULTIPLE DWELLING A                   NaN                   NaN
# 1387   MULTIPLE DWELLING B                   NaN                   NaN
# 1390   MULTIPLE DWELLING A                   NaN                   NaN
# 1473   MULTIPLE DWELLING A                   NaN                   NaN
# 1979   MULTIPLE DWELLING A                   NaN                   NaN
# 1984   MULTIPLE DWELLING A                   NaN                   NaN
# 2320   MULTIPLE DWELLING A                   NaN                   NaN
# 2724   MULTIPLE DWELLING A                   NaN                   NaN
# 3646   MULTIPLE DWELLING A                   NaN                   NaN
# 3767   MULTIPLE DWELLING A                   NaN                   NaN
# 3855   MULTIPLE DWELLING A                   NaN                   NaN
# 3863   MULTIPLE DWELLING A                   NaN                   NaN
# 3881   MULTIPLE DWELLING A                   NaN                   NaN
# 4425   MULTIPLE DWELLING A                   NaN                   NaN
# 6659   MULTIPLE DWELLING A                   NaN                   NaN
# 7813   MULTIPLE DWELLING A                   NaN                   NaN
# 7817   MULTIPLE DWELLING A  COOP/CONDO PLAN FILE                   NaN
# 7819   MULTIPLE DWELLING A                   NaN                   NaN
# 7827   MULTIPLE DWELLING A                   NaN                   NaN
# 7829   MULTIPLE DWELLING A                   NaN                   NaN
# 7834   MULTIPLE DWELLING A                   NaN                   NaN
# 7877   MULTIPLE DWELLING B                   NaN                   NaN
# 7878   MULTIPLE DWELLING A                   NaN                   NaN
# 7945   MULTIPLE DWELLING A                   NaN                   NaN
# 7951   MULTIPLE DWELLING A                   NaN                   NaN
# 8227   MULTIPLE DWELLING A                   NaN                   NaN
# 8506   MULTIPLE DWELLING A                   NaN                   NaN
# 8720   MULTIPLE DWELLING A                   NaN                   NaN
# 9851   MULTIPLE DWELLING A            ARTICLE 11                   NaN
# 9854   MULTIPLE DWELLING A            ARTICLE 11                   NaN
# 9857   MULTIPLE DWELLING A                   NaN                   NaN
# 9867   MULTIPLE DWELLING A            ARTICLE 11                   NaN
# 9869   MULTIPLE DWELLING A                   NaN                   NaN
# 12027  MULTIPLE DWELLING A                   NaN                   NaN
# 12286  MULTIPLE DWELLING A      ARTICLES 14 & 15            ARTICLE 11
# 12431  MULTIPLE DWELLING B                   NaN                   NaN
# 12752  MULTIPLE DWELLING A                   NaN                   NaN
# 12809  MULTIPLE DWELLING B                   NaN                   NaN
# 12811  MULTIPLE DWELLING A                   NaN                   NaN
# 12887  MULTIPLE DWELLING A                   NaN                   NaN
# 12913  MULTIPLE DWELLING A                   NaN                   NaN
# 15631  MULTIPLE DWELLING A          421-A (1-15)                   NaN
# 16223  MULTIPLE DWELLING A        GARDEN COMPLEX                  J-51
# 17850  MULTIPLE DWELLING A                   NaN                   NaN
# 19002  MULTIPLE DWELLING A                   NaN                   NaN
# 19166  MULTIPLE DWELLING A        GARDEN COMPLEX                   NaN
# 19167  MULTIPLE DWELLING A                   NaN                   NaN
# 19169  MULTIPLE DWELLING A                   NaN                   NaN
# 19171  MULTIPLE DWELLING A                   NaN                   NaN
# 20161  MULTIPLE DWELLING A                   NaN                   NaN
# 22002  MULTIPLE DWELLING A                   NaN                   NaN
# 22313  MULTIPLE DWELLING A                   NaN                   NaN
# 24181  MULTIPLE DWELLING A        GARDEN COMPLEX                   NaN
# 25351  MULTIPLE DWELLING A                   NaN                   NaN
# 25352  MULTIPLE DWELLING B                   NaN                   NaN
# 25353  MULTIPLE DWELLING A                   NaN                   NaN
# 25354  MULTIPLE DWELLING A                   NaN                   NaN
# 25355  MULTIPLE DWELLING A                   NaN                   NaN
# 25356  MULTIPLE DWELLING A  NON-EVICT COOP/CONDO                   NaN
# 25357  MULTIPLE DWELLING A  NON-EVICT COOP/CONDO                   NaN
# 25358  MULTIPLE DWELLING A                   NaN                   NaN
# 25359  MULTIPLE DWELLING A                   NaN                   NaN
# 25367  MULTIPLE DWELLING A  NON-EVICT COOP/CONDO                   NaN
# 27067  MULTIPLE DWELLING A                   NaN                   NaN
# 27075  MULTIPLE DWELLING A                   NaN                   NaN
# 27327  MULTIPLE DWELLING A                   NaN                   NaN
# 27328  MULTIPLE DWELLING A                   NaN                   NaN
# 27329  MULTIPLE DWELLING A                   NaN                   NaN
# 27330  MULTIPLE DWELLING A                   NaN                   NaN
# 27331  MULTIPLE DWELLING A                  J-51                   NaN
# 27332  MULTIPLE DWELLING A                   NaN                   NaN
# 27333  MULTIPLE DWELLING A                   NaN                   NaN
# 27334  MULTIPLE DWELLING A                   NaN                   NaN
# 27335  MULTIPLE DWELLING A  COOP/CONDO PLAN FILE                   NaN
# 27336  MULTIPLE DWELLING A                   NaN                   NaN
# 27337  MULTIPLE DWELLING A  NON-EVICT COOP/CONDO                   NaN
# 27383  MULTIPLE DWELLING A                   NaN                   NaN
# 28412  MULTIPLE DWELLING A                   NaN                   NaN
# 28414  MULTIPLE DWELLING A        GARDEN COMPLEX                   NaN
# 28417  MULTIPLE DWELLING A                   NaN                   NaN
# 28419  MULTIPLE DWELLING A                   NaN                   NaN
# 28422  MULTIPLE DWELLING A            ARTICLE 11                   NaN
# 28768  MULTIPLE DWELLING B                   NaN                   NaN
# 28769  MULTIPLE DWELLING A                   NaN                   NaN
# 28771  MULTIPLE DWELLING A                   NaN                   NaN
# 28925  MULTIPLE DWELLING A         ROOMING HOUSE  NON-EVICT COOP/CONDO
# 31293  MULTIPLE DWELLING A                   NaN                   NaN
# 31294  MULTIPLE DWELLING A          421-A (1-15)                   NaN
# 31296  MULTIPLE DWELLING A            421-A (16)                   NaN
# 31297  MULTIPLE DWELLING A        GARDEN COMPLEX                   NaN
# 31298  MULTIPLE DWELLING A                   NaN                   NaN
# 31623  MULTIPLE DWELLING A                   NaN                   NaN
# 31865  MULTIPLE DWELLING A                   NaN                   NaN
# 31866  MULTIPLE DWELLING A                   NaN                   NaN
# 34062  MULTIPLE DWELLING A                   NaN                   NaN
# 37404  MULTIPLE DWELLING A                   NaN                   NaN
# 38679  MULTIPLE DWELLING A                   NaN                   NaN
# 38680  MULTIPLE DWELLING A                   NaN                   NaN
# 38681  MULTIPLE DWELLING A                   NaN                   NaN
# 38682  MULTIPLE DWELLING A                   NaN                   NaN
# 42522                  NaN   MULTIPLE DWELLING A        GARDEN COMPLEX
# 48541                  NaN   MULTIPLE DWELLING A          421-A (1-15)
# 48928  MULTIPLE DWELLING A                   NaN                   NaN
#
#        LATITUDE  LONGITUDE
# 148         NaN        NaN
# 234         NaN        NaN
# 293         NaN        NaN
# 401         NaN        NaN
# 1267        NaN        NaN
# 1268        NaN        NaN
# 1387        NaN        NaN
# 1390        NaN        NaN
# 1473        NaN        NaN
# 1979        NaN        NaN
# 1984        NaN        NaN
# 2320        NaN        NaN
# 2724        NaN        NaN
# 3646        NaN        NaN
# 3767        NaN        NaN
# 3855        NaN        NaN
# 3863        NaN        NaN
# 3881        NaN        NaN
# 4425        NaN        NaN
# 6659        NaN        NaN
# 7813        NaN        NaN
# 7817        NaN        NaN
# 7819        NaN        NaN
# 7827        NaN        NaN
# 7829        NaN        NaN
# 7834        NaN        NaN
# 7877        NaN        NaN
# 7878        NaN        NaN
# 7945        NaN        NaN
# 7951        NaN        NaN
# 8227        NaN        NaN
# 8506        NaN        NaN
# 8720        NaN        NaN
# 9851        NaN        NaN
# 9854        NaN        NaN
# 9857        NaN        NaN
# 9867        NaN        NaN
# 9869        NaN        NaN
# 12027       NaN        NaN
# 12286       NaN        NaN
# 12431       NaN        NaN
# 12752       NaN        NaN
# 12809       NaN        NaN
# 12811       NaN        NaN
# 12887       NaN        NaN
# 12913       NaN        NaN
# 15631       NaN        NaN
# 16223       NaN        NaN
# 17850       NaN        NaN
# 19002       NaN        NaN
# 19166       NaN        NaN
# 19167       NaN        NaN
# 19169       NaN        NaN
# 19171       NaN        NaN
# 20161       NaN        NaN
# 22002       NaN        NaN
# 22313       NaN        NaN
# 24181       NaN        NaN
# 25351       NaN        NaN
# 25352       NaN        NaN
# 25353       NaN        NaN
# 25354       NaN        NaN
# 25355       NaN        NaN
# 25356       NaN        NaN
# 25357       NaN        NaN
# 25358       NaN        NaN
# 25359       NaN        NaN
# 25367       NaN        NaN
# 27067       NaN        NaN
# 27075       NaN        NaN
# 27327       NaN        NaN
# 27328       NaN        NaN
# 27329       NaN        NaN
# 27330       NaN        NaN
# 27331       NaN        NaN
# 27332       NaN        NaN
# 27333       NaN        NaN
# 27334       NaN        NaN
# 27335       NaN        NaN
# 27336       NaN        NaN
# 27337       NaN        NaN
# 27383       NaN        NaN
# 28412       NaN        NaN
# 28414       NaN        NaN
# 28417       NaN        NaN
# 28419       NaN        NaN
# 28422       NaN        NaN
# 28768       NaN        NaN
# 28769       NaN        NaN
# 28771       NaN        NaN
# 28925       NaN        NaN
# 31293       NaN        NaN
# 31294       NaN        NaN
# 31296       NaN        NaN
# 31297       NaN        NaN
# 31298       NaN        NaN
# 31623       NaN        NaN
# 31865       NaN        NaN
# 31866       NaN        NaN
# 34062       NaN        NaN
# 37404       NaN        NaN
# 38679       NaN        NaN
# 38680       NaN        NaN
# 38681       NaN        NaN
# 38682       NaN        NaN
# 42522       NaN        NaN
# 48541       NaN        NaN
# 48928       NaN        NaN

# %%
import re

def fix_building_no(building_no):
    if pd.isna(building_no):
        return None
    s = str(building_no).strip()
    # Handle range: take first number (but don't update df)
    if " TO " in s:
        return s.split(" TO ")[0].strip()
    # Handle decimal: convert to "n 1/2" if .5, else keep as int
    m = re.match(r'^(\d+)\.5$', s)
    if m:
        return f"{int(float(s))} 1/2"
    # Just return as string
    return s

# Load data (if not already loaded)
try:
    df
except NameError:
    df = pd.read_csv("listings_with_coordinates.csv")

# Find rows with missing coordinates and problematic BUILDING_NO
mask = (df['LATITUDE'].isna() | df['LONGITUDE'].isna())
problem_rows = df[mask].copy()

for idx, row in problem_rows.iterrows():
    orig_building_no = row['BUILDING_NO']
    s = str(orig_building_no).strip() if pd.notna(orig_building_no) else ""
    fixed_building_no = fix_building_no(orig_building_no)
    if fixed_building_no and fixed_building_no != s:
        print(f"Processing: BUILDING_NO='{orig_building_no}' (using '{fixed_building_no}') on STREET='{row['STREET']}'")
        lat, lon = get_lat_lon(
            house_number=fixed_building_no,
            street=str(row['STREET']),
            borough=str(row['BOROUGH'])
        )
        if lat and lon:
            df.at[idx, 'LATITUDE'] = lat
            df.at[idx, 'LONGITUDE'] = lon
            if re.match(r'^\d+\.5$', s):
                df.at[idx, 'BUILDING_NO'] = fixed_building_no

# Save updated DataFrame
df.to_csv("listings_with_coordinates.csv", index=False)
print("Done fixing and updating coordinates.")
